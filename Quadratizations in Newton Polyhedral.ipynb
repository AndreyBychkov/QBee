# %%
import sympy as sp
from qbee.examples import *
from qbee.experiments import show_convex_hull_report

# %% [markdown]
# ### Circular 3

# %%
system = generate_circular(3)
show_convex_hull_report(system)
# Out:
# Elapsed time: 0.007s.
# Upper bound of search is 5
# Order of quadratization: green if monom is in convex hull and red if it's not.
# 3: x^{2}, x y, y^{2},
# 4: x^{2}, y^{2}, x^{3}, y^{3},
# 5: x y, y^{2}, x^{3}, x y^{2}, y^{3},
# 5: x y, x^{3}, y^{3}, x^{3} y, x y^{3},
# 5: y^{2}, x^{3}, y^{3}, x^{4}, x y^{3},
# 5: x^{2}, x y, y^{2}, x^{3}, y^{3},
# 5: x^{2}, x y, x^{3}, x^{2} y, y^{3},
# 5: x^{2}, x^{3}, y^{3}, x^{3} y, y^{4},
# ...
# Order of quadratization: green if monom is vertex of convex hull and red if it's not.
# 3: x^{2}, x y, y^{2}, [0/2]
# 4: x^{2}, y^{2}, x^{3}, y^{3}, [2/2]
# 5: x y, y^{2}, x^{3}, x y^{2}, y^{3}, [2/2]
# 5: x y, x^{3}, y^{3}, x^{3} y, x y^{3}, [2/2]
# 5: y^{2}, x^{3}, y^{3}, x^{4}, x y^{3}, [2/2]
# 5: x^{2}, x y, y^{2}, x^{3}, y^{3}, [2/2]
# 5: x^{2}, x y, x^{3}, x^{2} y, y^{3}, [2/2]
# 5: x^{2}, x^{3}, y^{3}, x^{3} y, y^{4}, [2/2]

# %% [markdown]
# ### Circular 4

# %%
system = generate_circular(4)
show_convex_hull_report(system)
# Out:
# Elapsed time: 0.269s.
# Upper bound of search is 6
# Order of quadratization: green if monom is in convex hull and red if it's not.
# 4: x^{3}, x^{2} y, x y^{2}, y^{3},
# 6: x^{3}, y^{3}, x^{5}, x^{4} y, x y^{4}, y^{5},
# 6: x^{2}, y^{2}, x^{3}, y^{3}, x^{4}, y^{4},
# 6: x^{3}, x y^{2}, y^{3}, x^{5}, x^{4} y, y^{5},
# 6: x y, x^{3}, x^{2} y, y^{3}, x^{4}, y^{4},
# 6: x y, y^{2}, x^{3}, x^{2} y^{2}, x^{5}, y^{5},
# 6: x^{3}, x^{2} y, y^{3}, x^{5}, x y^{4}, y^{5},
# 6: x^{2}, y^{2}, x^{3} y, x y^{3}, x^{5}, y^{5},
# 6: x^{2}, y^{3}, x y^{3}, x^{3} y^{2}, y^{6}, x^{7},
# 6: x^{3}, x^{2} y, y^{3}, x^{4}, y^{4}, y^{5},
# 6: x y, x^{3}, x y^{2}, y^{3}, x^{4}, y^{4},
# 6: x^{3}, x y^{2}, y^{3}, x^{4}, y^{4}, x^{5},
# 6: x^{2}, y^{2}, x^{3}, x^{2} y, x y^{2}, y^{3},
# 6: y^{2}, x^{3}, x^{3} y, x^{2} y^{3}, x^{6}, y^{7},
# 6: x^{3}, x^{2} y, x y^{2}, y^{3}, x^{4}, y^{4},
# 6: x^{3}, x y^{2}, y^{3}, x^{4}, y^{4}, x^{5},
# 6: x^{3}, x y^{2}, y^{3}, x^{5}, x y^{4}, y^{5},
# ...

# %% [markdown]
# ### Circular 5

# %%
system = generate_circular(5)
show_convex_hull_report(system)
# Out:
# Elapsed time: 0.032s.
# Upper bound of search is 6
# Order of quadratization: green if monom is in convex hull and red if it's not.
# 4: x^{4}, x^{3} y, x y^{3}, y^{4},
# 5: x^{4}, x^{3} y, x^{2} y^{2}, x y^{3}, y^{4},
# 6: x^{4}, x^{3} y, x y^{3}, y^{4}, x^{5}, y^{5},
# ...
# Order of quadratization: green if monom is vertex of convex hull and red if it's not.
# 4: x^{4}, x^{3} y, x y^{3}, y^{4}, [0/2]
# 5: x^{4}, x^{3} y, x^{2} y^{2}, x y^{3}, y^{4}, [0/2]
# 6: x^{4}, x^{3} y, x y^{3}, y^{4}, x^{5}, y^{5}, [2/2]

# %% [markdown]
# ### Circular 6

# %%
system = generate_circular(6)
show_convex_hull_report(system)
# Out:
# Elapsed time: 18.296s.
# Upper bound of search is 7
# Order of quadratization: green if monom is in convex hull and red if it's not.
# 5: x^{5}, x^{4} y, x^{3} y^{2}, x y^{4}, y^{5},
# 5: x^{5}, x^{4} y, x^{2} y^{3}, x y^{4}, y^{5},
# 6: x^{5}, x^{4} y, x^{3} y^{2}, x^{2} y^{3}, x y^{4}, y^{5},
# 7: x^{5}, x^{4} y, x^{2} y^{3}, x y^{4}, y^{5}, x^{6}, y^{6},
# 7: x^{5}, x^{4} y, x^{3} y^{2}, x y^{4}, y^{5}, x^{6}, y^{6},
# 7: x^{3}, x y^{3}, y^{5}, x^{4} y^{2}, y^{8}, x^{5} y^{4}, x^{10},
# 7: x^{5}, x^{3} y^{2}, x^{2} y^{3}, y^{5}, x^{9}, x^{3} y^{6}, y^{9},
# 7: x^{5}, x^{3} y^{2}, x^{2} y^{3}, y^{5}, x^{9}, x^{6} y^{3}, y^{9},
# 7: y^{3}, x^{3} y, x^{5}, x^{2} y^{4}, x^{8}, x^{4} y^{5}, y^{10},
# 7: x^{5}, x^{3} y^{2}, y^{5}, x^{9}, x^{3} y^{6}, x^{2} y^{7}, y^{13},
# 7: x^{5}, x^{2} y^{3}, y^{5}, x^{7} y^{2}, x^{6} y^{3}, y^{9}, x^{13},
# ...
# Order of quadratization: green if monom is vertex of convex hull and red if it's not.
# 5: x^{5}, x^{4} y, x^{3} y^{2}, x y^{4}, y^{5}, [0/2]
# ...

# %% [markdown]
# ### Hill 5

# %%
system = generate_hill(5)
show_convex_hull_report(system)
# Out:
# Elapsed time: 0.006s.
# Upper bound of search is 6
# Order of quadratization: green if monom is in convex hull and red if it's not.
# 2: t^{3}, i t^{4},
# 2: i t^{2}, i t^{4},
# 3: i t^{2}, i t^{4}, i t^{6},
# 3: i t^{2}, i t^{3}, i t^{4},
# 3: i t, i t^{3}, i t^{4},
# 3: i t^{2}, i t^{4}, i^{2} t^{5},
# 3: i t, t^{2}, i t^{4},
# 3: i^{2} t, t^{3}, i t^{4},
# 3: t^{2}, i t^{3}, i t^{4},
# 3: i t^{2}, i^{2} t^{3}, i t^{4},
# 4: i t, t^{2}, i^{2} t^{2}, i t^{4},
# 4: i t^{2}, i t^{4}, i^{2} t^{5}, i^{2} t^{6},
# 4: i^{2} t, t^{3}, i^{2} t^{3}, i t^{4},
# 4: i^{2} t, i t^{2}, i^{2} t^{3}, i t^{4},
# 4: i t^{2}, i t^{4}, i t^{5}, i^{2} t^{6},
# 4: i t, i t^{3}, i^{2} t^{3}, i t^{4},
# 4: i t^{2}, i^{2} t^{3}, i t^{4}, i t^{6},
# 4: i t, t^{2}, i^{2} t^{3}, i t^{4},
# 4: i t, i t^{3}, i t^{4}, i^{2} t^{4},
# 4: i t^{2}, i t^{4}, i^{2} t^{5}, i^{2} t^{7},
# 4: i t^{2}, i t^{4}, i^{2} t^{5}, i^{3} t^{8},
# 4: i t^{2}, i^{2} t^{5}, i^{2} t^{7}, i^{3} t^{10},
# ...

# %% [markdown]
# ### Hill 10

# %%
system = generate_hill(10)
show_convex_hull_report(system)

# %% [markdown]
# ### Hill 15

# %%
system = generate_hill(15)
show_convex_hull_report(system)

# %% [markdown]
# ### Hard 2

# %%
system = generate_hard(2)
show_convex_hull_report(system)
# Out:
# Elapsed time: 109.297s.
# Upper bound of search is 13

# %% [markdown]
# ### Hard 3

# %%
system = generate_hard(3)
show_convex_hull_report(system)

# %% [markdown]
# ### Conjecture 2

# %%
system = generate_lifeware_conjecture(2)
show_convex_hull_report(system)
# Out:
# Elapsed time: 0.019s.
# Upper bound of search is 6
# Order of quadratization: green if monom is in convex hull and red if it's not.
# 3: x_{0}^{3}, x_{0} x_{1}^{2}, x_{1}^{3},
# 3: x_{0}^{3}, x_{0}^{2} x_{1}, x_{1}^{3},
# 4: x_{0}^{2}, x_{1}^{2}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2},
# 4: x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3},
# 4: x_{0}^{2}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3},
# 4: x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2},
# 5: x_{0}^{2}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{0}^{2} x_{1}^{2}, x_{1}^{4},
# 5: x_{0}^{2}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3}, x_{1}^{4},
# 5: x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{4},
# 5: x_{0}^{2}, x_{0} x_{1}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{1}^{3},
# 5: x_{0}^{2}, x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{1}^{3},
# 5: x_{0}^{2}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{0} x_{1}^{3}, x_{1}^{4},
# 5: x_{0} x_{1}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3},
# ...

# %% [markdown]
# ### Conjecture 3

# %%
system = generate_lifeware_conjecture(3)
show_quadratizations_is_in_newton_polyhedral(system, 8)

# %%
show_newton_polyhedral_vertices_in_quadratization(system, 8)

# %% [markdown]
# ### Dense eq=2 ord=3

# %%
system = generate_dense_polynomial(2, 3)
show_convex_hull_report(system, 6)
# Out:
# Order of quadratization: green if monom is in convex hull and red if it's not.
# 3: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2},
# 5: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0}^{3}, x_{1}^{3},
# 6: x_{0}^{2}, x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{1}^{3}, x_{0} x_{1}^{3},
# 6: x_{0}^{2}, x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{4},
# 6: x_{0}^{2}, x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{3}, x_{1}^{4},
# 6: x_{0}^{2}, x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3},
# 6: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0}^{3}, x_{0} x_{1}^{2}, x_{1}^{3},
# 6: x_{0} x_{1}, x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{1}^{3}, x_{0}^{4},
# 6: x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{1}^{3}, x_{0}^{4}, x_{0} x_{1}^{3},
# 6: x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{1}^{3}, x_{0}^{4}, x_{1}^{4},
# 6: x_{0}^{2}, x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{1}^{3}, x_{1}^{4},
# 6: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0}^{3}, x_{1}^{3}, x_{0}^{4},
# ...

# %% [markdown]
# ### Dense eq=2 ord=4

# %%
system = generate_dense_polynomial(2, 4)
show_convex_hull_report(system, 8)
# Out:
# Order of quadratization: green if monom is in convex hull and red if it's not.
# 6: x_{0}^{2}, x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3},
# 7: x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3}, x_{0}^{4}, x_{1}^{4},
# 7: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3},
# 7: x_{0}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3}, x_{0}^{4}, x_{1}^{4},
# 7: x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3}, x_{0}^{4}, x_{1}^{4},
# 7: x_{1}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3}, x_{0}^{4}, x_{1}^{4},
# 7: x_{0}^{2}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3}, x_{0}^{4}, x_{1}^{4},
# 7: x_{0} x_{1}, x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3}, x_{0}^{4}, x_{1}^{4},
# 7: x_{0}^{3}, x_{0}^{2} x_{1}, x_{0} x_{1}^{2}, x_{1}^{3}, x_{0}^{4}, x_{0}^{2} x_{1}^{2}, x_{1}^{4},
# ...

# %% [markdown]
# ### Dense eq=3 ord=3

# %%
system = generate_dense_polynomial(3, 3)
show_convex_hull_report(system, 10)
# Out:
# Order of quadratization: green if monom is in convex hull and red if it's not.
# 6: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2},
# 10: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2}, x_{0}^{3}, x_{1}^{3}, x_{0} x_{1} x_{2}, x_{2}^{3},
# 10: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2}, x_{0}^{3}, x_{1}^{3}, x_{0} x_{1} x_{2}, x_{2}^{3},
# ...
# Order of quadratization: green if monom is vertex of convex hull and red if it's not.
# 6: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2}, [0/3]
# 10: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2}, x_{0}^{3}, x_{1}^{3}, x_{0} x_{1} x_{2}, x_{2}^{3}, [3/3]
# 10: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2}, x_{0}^{3}, x_{1}^{3}, x_{0} x_{1} x_{2}, x_{2}^{3}, [3/3]

# %%
show_convex_hull_report(system, 10)
# Out:
# Order of quadratization: green if monom is in convex hull and red if it's not.
# 6: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2},
# 10: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2}, x_{0}^{3}, x_{1}^{3}, x_{0} x_{1} x_{2}, x_{2}^{3},
# 10: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2}, x_{0}^{3}, x_{1}^{3}, x_{0} x_{1} x_{2}, x_{2}^{3},
# ...
# Order of quadratization: green if monom is vertex of convex hull and red if it's not.
# 6: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2}, [0/3]
# 10: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2}, x_{0}^{3}, x_{1}^{3}, x_{0} x_{1} x_{2}, x_{2}^{3}, [3/3]
# 10: x_{0}^{2}, x_{0} x_{1}, x_{1}^{2}, x_{0} x_{2}, x_{1} x_{2}, x_{2}^{2}, x_{0}^{3}, x_{1}^{3}, x_{0} x_{1} x_{2}, x_{2}^{3}, [3/3]

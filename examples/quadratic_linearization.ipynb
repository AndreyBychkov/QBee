# %%
# %load_ext autoreload
# %autoreload 2

import sympy as sp
from qbee import *
from visualization import visualize

sp.init_printing()

x, y, z = sp.symbols('x, y, z')
dot_x, dot_y, dot_z = derivatives('x, y, z')
# Out:
# C:\Users\а\IdeaProjects\QBee\PythonPackage\quadratic_linearization.py:9: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# ### Simple systems

# %%
system = EquationSystem([
    sp.Eq(dot_x, x**3)
])

system.equations
# Out:
# ⎡          3⎤
# ⎣\dot x = x ⎦

# %%
quadratic_linearize(system).system.equations
# Out:
# ⎡                                      2⎤
# ⎣\dot x = x⋅y_{0}, \dot y_{0} = 2⋅y_{0} ⎦

# %%
system = EquationSystem([
    sp.Eq(dot_x, x**3),
    sp.Eq(dot_y, x * z**2),
    sp.Eq(dot_z, z)
])

system.equations
# Out:
# ⎡          3              2            ⎤
# ⎣\dot x = x , \dot y = x⋅z , \dot z = z⎦

# %%
quadratic_linearize(system).system.equations
# Out:
# ⎡
# ⎣\dot x = x⋅y_{1}, \dot y = x⋅y_{0}, \dot z = z, \dot y_{0} = 2⋅y_{0}, \dot y_
#
#              2⎤
# {1} = 2⋅y_{1} ⎦

# %% [markdown]
# # Example 6.3.5 from [article](https://www2.eecs.berkeley.edu/Pubs/TechRpts/2012/EECS-2012-217.pdf)
#
# There are several methods to quadratic-linearize a system.

# %%
system = EquationSystem([
    sp.Eq(dot_x, 1 / (1 + sp.exp(x)))
])

system.equations
# Out:
# ⎡           1   ⎤
# ⎢\dot x = ──────⎥
# ⎢          x    ⎥
# ⎣         ℯ  + 1⎦

# %%
poly_system = polynomialize(system)
poly_system.equations
# Out:
# ⎡                                                                   3⎤
# ⎣\dot x = y_{1}, \dot y_{0} = y_{0}⋅y_{1}, \dot y_{1} = -y_{0}⋅y_{1} ⎦

# %%
ql_result = quadratic_linearize(poly_system, mode='optimal', method_optimal='bfs', log_file='log.csv')
ql_result.system.equations
# Out:
# ⎡
# ⎣\dot x = y_{1}, \dot y_{0} = y_{0}⋅y_{1}, \dot y_{1} = -y_{1}⋅y_{2}, \dot y_{
#
#                           2⎤
# 2} = y_{1}⋅y_{2} - 2⋅y_{2} ⎦

# %%
ql_result.statistics
# Out:
# steps: 7
# Method's name: BFS
# depth: 1

# %%
visualize('log.csv', figsize=(20, 20), node_size=500, edge_width=0.5, edge_label_font_size=9)

# %%
ql_result = quadratic_linearize(poly_system, mode='optimal', method_optimal='iddfs',  log_file='log.csv')
ql_result.system.equations
# Out:
# ⎡
# ⎣\dot x = y_{1}, \dot y_{0} = y_{0}⋅y_{1}, \dot y_{1} = -y_{1}⋅y_{2}, \dot y_{
#
#                           2⎤
# 2} = y_{1}⋅y_{2} - 2⋅y_{2} ⎦

# %%
ql_result.statistics
# Out:
# steps: 4
# Method's name: ID-DFS
# depth: 1

# %%
visualize('log.csv', figsize=(20, 20), node_size=500, edge_width=0.5, edge_label_font_size=9)

# %% [markdown]
# # $x^2y^2z^2$ Example

# %%
w = sp.symbols('w')
dot_w = derivatives('w')

system = EquationSystem([
    sp.Eq(dot_x, 0),
    sp.Eq(dot_y, 0),
    sp.Eq(dot_z, 0),
    sp.Eq(dot_w, x**2 * y**2 * z**2)
])

poly_system = polynomialize(system)

poly_system.equations
# Out:
# ⎡                                              2  2  2⎤
# ⎣\dot x = 0, \dot y = 0, \dot z = 0, \dot w = x ⋅y ⋅z ⎦

# %%
ql_result = quadratic_linearize(poly_system, mode='optimal', method_optimal='bfs', log_file='log.csv')
ql_result.system.equations
# Out:
# [\dot x = 0, \dot y = 0, \dot z = 0, \dot w = y_{0}⋅z, \dot y_{0} = 0]

# %%
ql_result.statistics
# Out:
# steps: 4
# Method's name: BFS
# depth: 1

# %%
visualize('log.csv', figsize=(20, 20), node_size=500, edge_width=0.5, edge_label_font_size=9)

# %%
ql_result = quadratic_linearize(poly_system, mode='optimal', method_optimal='iddfs', log_file='log.csv')
ql_result.system.equations
# Out:
# [\dot x = 0, \dot y = 0, \dot z = 0, \dot w = y_{0}⋅z, \dot y_{0} = 0]

# %%
ql_result.statistics
# Out:
# steps: 2
# Method's name: ID-DFS
# depth: 1

# %%
visualize('log.csv', figsize=(20, 20), node_size=500, edge_width=0.5, edge_label_font_size=9)

# %% [markdown]
# # Tough Example

# %%
system = EquationSystem([
    sp.Eq(dot_x, x / (1 + sp.exp(x))),
])

system.equations
# Out:
# ⎡           x   ⎤
# ⎢\dot x = ──────⎥
# ⎢          x    ⎥
# ⎣         ℯ  + 1⎦

# %%
poly_system = polynomialize(system)
poly_system.equations
# Out:
# ⎡                                                                         3⎤
# ⎣\dot x = x⋅y_{1}, \dot y_{0} = x⋅y_{0}⋅y_{1}, \dot y_{1} = -x⋅y_{0}⋅y_{1} ⎦

# %% [markdown]
# ## BFS

# %%
ql_result = quadratic_linearize(poly_system, method_optimal='bfs', limit_depth=2, debug='info', log_file='log.csv')
ql_result.system.equations
# Out:
# ...
# ⎡
# ⎣\dot x = y_{3}, \dot y_{0} = y_{0}⋅y_{3}, \dot y_{1} = -y_{1}⋅y_{2}, \dot y_{
#
#                           2
# 2} = y_{1}⋅y_{2} - 2⋅y_{2}  + y_{2}⋅y_{3}, \dot y_{3} = y_{1}⋅y_{3} - y_{2}⋅y_
#
#    ⎤
# {3}⎦

# %%
ql_result.statistics
# Out:
# steps: 115
# Method's name: BFS
# depth: 2

# %% [markdown]
# ## Tuned ID-DFS

# %%
ql_result = quadratic_linearize(poly_system, method_optimal='iddfs', heuristics='default',
                                initial_max_depth=2, limit_depth=2, debug='info', log_file='log.csv')
ql_result.system.equations
# Out:
# ...
# ⎡
# ⎣\dot x = y_{3}, \dot y_{0} = y_{0}⋅y_{3}, \dot y_{1} = -y_{1}⋅y_{2}, \dot y_{
#
#                           2
# 2} = y_{1}⋅y_{2} - 2⋅y_{2}  + y_{2}⋅y_{3}, \dot y_{3} = y_{1}⋅y_{3} - y_{2}⋅y_
#
#    ⎤
# {3}⎦

# %%
ql_result.statistics
# Out:
# steps: 43
# Method's name: ID-DFS
# depth: 2
